# %%
import pandas as pd
import numpy as np

# %%
# CONVERSION STEPS
# Step 1: Discussions around 6 prefixes which cross over Budget Programs because they are a large set of records.  
# Step 1, cont: We are calling these Categories A, B, C, D: Prefixes 00, RW, XE, XL, TA, RO, (DM)
# Step 2: When Step 1 is completed, then go and do every Budget Program A - Z 
# Step 2.1: Discussion around Budget Program E, X from email

# %%
# Read csv file, change path

# df = pd.read_csv('C:\WSDOTLocal\All_Data_20241023_151327.csv', encoding = "ISO-8859-1", low_memory = False)
# df = pd.read_csv('C:\WSDOTLocal\All_Data_20241030_162738.csv', encoding = "ISO-8859-1", low_memory = False)
# df_extract = pd.read_csv('C:\WSDOTLocal\All_Data_20241030_165111.csv', encoding = "ISO-8859-1", low_memory = False)
# df_extract = pd.read_csv('C:\WSDOTLocal\All_Data_20241031_170020.csv', encoding = "ISO-8859-1", low_memory = False)
# df_extract = pd.read_csv('C:\WSDOTLocal\All_Data_20241031_170020.csv', dtype = str, low_memory = False)
df_extract = pd.read_csv('C:\WSDOTLocal\All_Data_20241031_170020.csv', encoding = "ISO-8859-1", low_memory = False)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\W'
# <>:8: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\gulleyj\AppData\Local\Temp\ipykernel_27812\1834643900.py:8: SyntaxWarning: invalid escape sequence '\W'
#   df_extract = pd.read_csv('C:\WSDOTLocal\All_Data_20241031_170020.csv', encoding = "ISO-8859-1", low_memory = False)

# %%
df = df_extract[[
    'WORD_WSDOT_WO_DESCRIPTION',
    'GRUP_WSDOT_WORK_ORDER',
    'GRUP_WSDOT_GROUP',
    'GRUP_WSDOT_GROUP_DESC',
    'GRUP_WSDOT_STATUS',
    'GRUP_WSDOT_PROJ_FED_2', 
    'GRUP_WSDOT_PROJ_LOC_2',
    'GRUP_FUND',
    'GRUP_WSDOT_APPR_STA',
    'GRUP_WSDOT_ACTIVITY',
    'GRUP_WSDOT-CNTRL-SEC-IND',
    'GRUP_WSDOT-PIN-IND',
    'GRUP_WSDOT-LABOR-IND',
    'GRUP_WSDOT-PARCEL-IND',
    'GRUP_WSDOT-PAY-AGREE-2',
    'GRUP_WSDOT-DAMAGE-CODE',
    'GRUP_WSDOT-FIN-CD-FED', 
    'GRUP_WSDOT-FIN-CD-LOC', 
    'GRUP_WSDOT-FIN-CD-STA',
    'CSPA_WSDOT-CNTRL-SECT',
    'CSPA_WSDOT-PIN',
    'PFST_PROGRAM_PROVIDER',
]].copy()

# %%
# temp until Vijay can modify
# strip fields due to how the extracts are received

df['WORD_WSDOT_WO_DESCRIPTION'] = df['WORD_WSDOT_WO_DESCRIPTION'].str.strip()
df['GRUP_WSDOT_WORK_ORDER'] = df['GRUP_WSDOT_WORK_ORDER'].str.strip()
df['GRUP_WSDOT_GROUP'] = df['GRUP_WSDOT_GROUP'].str.strip()
df['GRUP_WSDOT_GROUP_DESC'] = df['GRUP_WSDOT_GROUP_DESC'].str.strip()
df['GRUP_WSDOT_STATUS'] = df['GRUP_WSDOT_STATUS'].str.strip()
df['GRUP_WSDOT_PROJ_FED_2'] = df['GRUP_WSDOT_PROJ_FED_2'].str.strip()
df['GRUP_WSDOT_PROJ_LOC_2'] = df['GRUP_WSDOT_PROJ_LOC_2'].str.strip()
df['GRUP_FUND'] = df['GRUP_FUND'].str.strip()
df['GRUP_WSDOT_APPR_STA'] = df['GRUP_WSDOT_APPR_STA'].str.strip()
df['GRUP_WSDOT_ACTIVITY'] = df['GRUP_WSDOT_ACTIVITY'].str.strip()
df['GRUP_WSDOT-CNTRL-SEC-IND'] = df['GRUP_WSDOT-CNTRL-SEC-IND'].str.strip()
df['GRUP_WSDOT-PIN-IND'] = df['GRUP_WSDOT-PIN-IND'].str.strip()
df['GRUP_WSDOT-LABOR-IND'] = df['GRUP_WSDOT-LABOR-IND'].str.strip()
df['GRUP_WSDOT-PARCEL-IND'] = df['GRUP_WSDOT-PARCEL-IND'].str.strip()
df['GRUP_WSDOT-PAY-AGREE-2'] = df['GRUP_WSDOT-PAY-AGREE-2'].str.strip()
df['GRUP_WSDOT-DAMAGE-CODE'] = df['GRUP_WSDOT-DAMAGE-CODE'].str.strip()
df['GRUP_WSDOT-FIN-CD-FED'] = df['GRUP_WSDOT-FIN-CD-FED'].str.strip()
df['GRUP_WSDOT-FIN-CD-LOC'] = df['GRUP_WSDOT-FIN-CD-LOC'].str.strip()
df['GRUP_WSDOT-FIN-CD-STA'] = df['GRUP_WSDOT-FIN-CD-STA'].str.strip()
df['CSPA_WSDOT-CNTRL-SECT'] = df['CSPA_WSDOT-CNTRL-SECT'].str.strip()
df['CSPA_WSDOT-PIN'] = df['CSPA_WSDOT-PIN'].str.strip()
df['PFST_PROGRAM_PROVIDER'] = df['PFST_PROGRAM_PROVIDER'].str.strip()

df['WORD_WSDOT_WO_DESCRIPTION'] = df['WORD_WSDOT_WO_DESCRIPTION'].replace('', np.nan)
df['GRUP_WSDOT_WORK_ORDER'] = df['GRUP_WSDOT_WORK_ORDER'].replace('', np.nan)
df['GRUP_WSDOT_GROUP'] = df['GRUP_WSDOT_GROUP'].replace('', np.nan)
df['GRUP_WSDOT_GROUP_DESC'] = df['GRUP_WSDOT_GROUP_DESC'].replace('', np.nan)
df['GRUP_WSDOT_STATUS'] = df['GRUP_WSDOT_STATUS'].replace('', np.nan)
df['GRUP_WSDOT_PROJ_FED_2'] = df['GRUP_WSDOT_PROJ_FED_2'].replace('', np.nan)
df['GRUP_WSDOT_PROJ_LOC_2'] = df['GRUP_WSDOT_PROJ_LOC_2'].replace('', np.nan)
df['GRUP_FUND'] = df['GRUP_FUND'].replace('', np.nan)
df['GRUP_WSDOT_APPR_STA'] = df['GRUP_WSDOT_APPR_STA'].replace('', np.nan)
df['GRUP_WSDOT_ACTIVITY'] = df['GRUP_WSDOT_ACTIVITY'].replace('', np.nan)
df['GRUP_WSDOT-CNTRL-SEC-IND'] = df['GRUP_WSDOT-CNTRL-SEC-IND'].replace('', 'N')
df['GRUP_WSDOT-PIN-IND'] = df['GRUP_WSDOT-PIN-IND'].replace('', 'N')
df['GRUP_WSDOT-LABOR-IND'] = df['GRUP_WSDOT-LABOR-IND'].replace('', np.nan)
df['GRUP_WSDOT-PARCEL-IND'] = df['GRUP_WSDOT-PARCEL-IND'].replace('', np.nan)
df['GRUP_WSDOT-PAY-AGREE-2'] = df['GRUP_WSDOT-PAY-AGREE-2'].replace('', np.nan)
df['GRUP_WSDOT-DAMAGE-CODE'] = df['GRUP_WSDOT-DAMAGE-CODE'].replace('', np.nan)
df['GRUP_WSDOT-FIN-CD-FED'] = df['GRUP_WSDOT-FIN-CD-FED'].replace('', np.nan)
df['GRUP_WSDOT-FIN-CD-LOC'] = df['GRUP_WSDOT-FIN-CD-LOC'].replace('', np.nan)
df['GRUP_WSDOT-FIN-CD-STA'] = df['GRUP_WSDOT-FIN-CD-STA'].replace('', np.nan)
df['CSPA_WSDOT-CNTRL-SECT'] = df['CSPA_WSDOT-CNTRL-SECT'].replace('', np.nan)
df['CSPA_WSDOT-PIN'] = df['CSPA_WSDOT-PIN'].replace('', np.nan)
df['PFST_PROGRAM_PROVIDER'] = df['PFST_PROGRAM_PROVIDER'].replace('', np.nan)

# %%
s = 'CE FOR INFORMATION ONLY - USE GROUP 60'

s[:3]
# Out:
# 'CE '

# %%
# add and populate helper columns

# add new fields
df[['Flag 1 Labor Ind',	
    'Flag 2 Cntrl Sec Ind',	
    'Flag 3 Pin Ind',	
    'Flag 4 Parcel Ind',
    'Budget_Program',
    'Budget_Sub_Program',
    'WO_Prefix']] = pd.DataFrame([['', '', '', '', '', '', '']], index=df.index)

df.loc[:, 'Flag 1 Labor Ind'] = df['GRUP_WSDOT-LABOR-IND']
df.loc[:, 'Flag 2 Cntrl Sec Ind'] = df['GRUP_WSDOT-CNTRL-SEC-IND']
df.loc[:, 'Flag 3 Pin Ind'] = df['GRUP_WSDOT-PIN-IND']
df.loc[:, 'Flag 4 Parcel Ind'] = df['GRUP_WSDOT-PARCEL-IND']
df.loc[:, 'Budget_Program'] = df['GRUP_WSDOT_ACTIVITY'].str.slice(0, 1) 
df.loc[:, 'Budget_Sub_Program'] = df['GRUP_WSDOT_ACTIVITY'].str.slice(0, 2) 
df.loc[:, 'WO_Prefix'] = df['GRUP_WSDOT_WORK_ORDER'].str.slice(0, 2)

# %%
# add and populate actpl columns

df[['Accounting Template',
    'Name',
    'Description',
    'Major Program', 
    'Program', 
    'Phase', 
    'Program Period',
    'Funding Profile',
    'Task',  
    'Task Order', 
    'Fund',
    'Appr Unit',
    'Activity',
    'Location']] = pd.DataFrame([['', '', '', '', '', '', '', '', '', '', '', '', '', '']], index=df.index)

# adding .fillna('') when concatenating
df.loc[:, 'Accounting Template'] = df['GRUP_WSDOT_WORK_ORDER'].fillna('') + df['GRUP_WSDOT_GROUP'].fillna('') + df['CSPA_WSDOT-CNTRL-SECT'].fillna('')
df.loc[:, 'Name'] = (df['WORD_WSDOT_WO_DESCRIPTION'].fillna('') + ' ' + df['GRUP_WSDOT_GROUP_DESC'].fillna('')).str.strip()
df.loc[:, 'Description'] = (df['PFST_PROGRAM_PROVIDER'].fillna('') + ' ' + df['GRUP_WSDOT-PAY-AGREE-2'].fillna('') + ' ' + df['GRUP_WSDOT-DAMAGE-CODE'].fillna('') + ' ' + df['GRUP_WSDOT-FIN-CD-FED'].fillna('') + ' ' + df['GRUP_WSDOT-FIN-CD-LOC'].fillna('') + ' ' + df['GRUP_WSDOT-FIN-CD-STA'].fillna('')).str.strip()

df.loc[:, 'Fund'] = df['GRUP_FUND']
df.loc[((df['GRUP_WSDOT_APPR_STA'].notna())), 'Appr Unit'] = df['GRUP_WSDOT_APPR_STA']
df.loc[((df['GRUP_WSDOT_APPR_STA'].isna())), 'Appr Unit'] = 'TBD'
df.loc[:, 'Activity'] = df['GRUP_WSDOT_ACTIVITY']
df.loc[:, 'Location'] = df['CSPA_WSDOT-CNTRL-SECT']

# %%
# Prefixes 00, RW, XE, XL, TA, RO, DM, Categories A, B, C, D
# MJPRGrules
# put code here

def mjprg_rules(df):
    
    df['Major Program'] = np.select(
        [
        # RO
        (df['WO_Prefix'].isin (['RO'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()),
        (df['WO_Prefix'].isin (['RO'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()),
        (df['WO_Prefix'].isin (['RO'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()),
    
        # RW
        (df['WO_Prefix'].isin (['RW'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()),
        (df['WO_Prefix'].isin (['RW'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()),
        (df['WO_Prefix'].isin (['RW'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()),
    
        # TA
        (df['WO_Prefix'].isin (['TA'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()),
        (df['WO_Prefix'].isin (['TA'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()),
        (df['WO_Prefix'].isin (['TA'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()),
    
        # 00        
        (df['WO_Prefix'].isin (['00'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()) &\
            (df['Budget_Program'].isin (['I', 'P', 'Z'])), # 'oo1FEDPRJ'           
        (df['WO_Prefix'].isin (['00'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()) &\
            (df['Budget_Program'] == 'W'), # 'oo2WSPRJ'            
        (df['WO_Prefix'].isin (['00'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()) &\
            (df['Budget_Program'].isin (['I', 'P', 'M', 'Z'])), # 'oo3REIMB'            
        (df['WO_Prefix'].isin (['00'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()) &\
            (df['Budget_Program'] == 'W'), # 'oo4WSPRJ'            
        (df['WO_Prefix'].isin (['00'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['I', 'P', 'W', 'X'])),
        (df['WO_Prefix'].isin (['00'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['Z'])),
        (df['WO_Prefix'].isin (['00'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['D', 'Q'])),
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['V'])),
    
        # XL
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()) &\
            (df['Budget_Program'].isin (['I', 'P', 'Y', 'Z'])),
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()) &\
            (df['Budget_Program'] == 'W'),
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()) &\
            (df['Budget_Program'].isin (['I', 'P'])),
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()) &\
            (df['Budget_Program'] == 'W'),   
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['I', 'P', 'W', 'X'])),
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['Z'])),
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['D', 'Q'])),
        (df['WO_Prefix'].isin (['XL'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['V'])),
    
        # XE
        (df['WO_Prefix'].isin (['XE'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()) &\
            (df['Budget_Program'].isin (['I', 'P', 'Y', 'Z'])),
        (df['WO_Prefix'].isin (['XE'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna()) &\
            (df['Budget_Program'] == 'W'),
        (df['WO_Prefix'].isin (['XE'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()) &\
            (df['Budget_Program'].isin (['I', 'P'])),
        (df['WO_Prefix'].isin (['XE'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].notna()) &\
            (df['Budget_Program'] == 'W'),    
        (df['WO_Prefix'].isin (['XE'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'].isin (['I', 'P', 'W', 'X'])),
        (df['WO_Prefix'].isin (['XE'])) &\
            (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
            (df['GRUP_WSDOT_PROJ_LOC_2'].isna()) &\
            (df['Budget_Program'] == 'Z'),
    
        # DM
        (df['WO_Prefix'].isin (['DM']))
        ],
        [
        # RO
        'FEDPRJ',
        'REIMB',
        'REIMB',
            
        # RW
        'FEDPRJ',
        'REIMB',
        'FEDPRJ',
            
        # TA
        'FEDPRJ',
        'REIMB',
        'FEDPRJ',
            
        # 00   
        'FEDPRJ',
        'WSPRJ',
        'REIMB',
        'WSPRJ',          
        'FEDPRJ',
        'REIMB',
        'REIMB',
        'REIMB',
            
         # XL
        'FEDPRJ',
        'WSPRJ',
        'REIMB',
        'WSPRJ',
        'FEDPRJ',
        'REIMB',
        'REIMB',
        'REIMB',
            
        # XE
        'FEDPRJ',
        'WSPRJ',
        'REIMB',
        'WSPRJ',
        'FEDPRJ',
        'REIMB',
            
        # DM
        'EMRGCY'
        ],
        default = ''
    )

# for testing
'''
[
        # RO
        'ro1FEDPRJ',
        'ro2REIMB',
        'ro3TBD',
            
        # RW
        'rw1FEDPRJ',
        'rw2REIMB',
        'rw3TBD',
            
        # TA
        'ta1FEDPRJ',
        'ta2REIMB',
        'ta3TBD',
            
        # 00   
        'oo1FEDPRJ',
        'oo2WSPRJ',
        'oo3REIMB',
        'oo4WSPRJ',
        'oo5TBD',
            
         # XL
        'xl1FEDPRJ',
        'xl2WSPRJ',
        'xl3REIMB',
        'xl4WSPRJ',
        'xl5FEDPRJ',
        'xl6REIMB',
        'xl7REIMB',
        'xl8PTCON',
            
        # XE
        'xe1FEDPRJ',
        'xe2WSPRJ',
        'xe3REIMB',
        'xe4WSPRJ',
        'xe5FEDPRJ',
        'xe6REIMB',
            
        # DM
        'dm1EMRGCY'
'''
# Out:
# "\n[\n        # RO\n        'ro1FEDPRJ',\n        'ro2REIMB',\n        'ro3TBD',\n            \n        # RW\n        'rw1FEDPRJ',\n        'rw2REIMB',\n        'rw3TBD',\n            \n        # TA\n        'ta1FEDPRJ',\n        'ta2REIMB',\n        'ta3TBD',\n            \n        # 00   \n        'oo1FEDPRJ',\n        'oo2WSPRJ',\n        'oo3REIMB',\n        'oo4WSPRJ',\n        'oo5TBD',\n            \n         # XL\n        'xl1FEDPRJ',\n        'xl2WSPRJ',\n        'xl3REIMB',\n        'xl4WSPRJ',\n        'xl5FEDPRJ',\n        'xl6REIMB',\n        'xl7REIMB',\n        'xl8PTCON',\n            \n        # XE\n        'xe1FEDPRJ',\n        'xe2WSPRJ',\n        'xe3REIMB',\n        'xe4WSPRJ',\n        'xe5FEDPRJ',\n        'xe6REIMB',\n            \n        # DM\n        'dm1EMRGCY'\n"

# %%
# Prefixes 00, RW, XE, XL, TA, RO, DM, Categories A, B, C, D
# FPRFLrules
# put code here

def fprfl_rules(df):

    df.loc[(df['WO_Prefix'].isin (['RO', 'RW', 'TA', '00', 'XL', 'XE', 'DM'])) &\
        (df['GRUP_WSDOT_PROJ_FED_2'].notna()), 'Funding Profile'] = df['GRUP_WSDOT_PROJ_FED_2']
    df.loc[(df['WO_Prefix'].isin (['RO', 'RW', 'TA', '00', 'XL', 'XE', 'DM'])) &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].notna()), 'Funding Profile'] = df['GRUP_WSDOT_PROJ_LOC_2']   
    df.loc[(df['WO_Prefix'].isin (['RO', 'RW', 'TA', '00', 'XL', 'XE', 'DM'])) &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].isna()), 'Funding Profile'] = 'STATEFUNDS'

# %%
# Prefixes 00, RW, XE, XL, TA, RO, DM, Categories A, B, C, D
# PROGrules
# put code here

def prg_rules(df):
    
    df.loc[(df['WO_Prefix'].isin (['RO', 'RW', 'TA', '00', 'XL', 'XE', 'DM'])) &\
        (df['CSPA_WSDOT-PIN'].notna()), 'Program'] = df['CSPA_WSDOT-PIN']
    df.loc[(df['WO_Prefix'].isin (['RO'])) &\
        (df['CSPA_WSDOT-PIN'].isna()), 'Program'] = df['GRUP_WSDOT_WORK_ORDER']
    df.loc[(df['WO_Prefix'].isin (['RW', 'TA', '00', 'XL', 'XE', 'DM'])) &\
        (df['CSPA_WSDOT-PIN'].isna()), 'Program'] = 'TBD'
    df.loc[(df['WO_Prefix'].isin (['DM'])), 'Program'] = df['GRUP_WSDOT_WORK_ORDER']

# %%
# Prefixes 00, RW, XE, XL, TA, RO, DM, Categories A, B, C, D
# PHPROGrules
# put code here

def phprg_rules(df):
    
    df.loc[(df['WO_Prefix'].isin (['00'])) &\
        ((df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:4] == 'C.E.') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:3] == 'CE ') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:3] == 'CE-')), 'Phase'] = 'CE'

    df.loc[(df['WO_Prefix'].isin (['00'])) &\
        ((df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:4] == 'C.E.') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:3] == 'CE ') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:3] == 'CE-') == False), 'Phase'] = 'CN'

    df.loc[(df['WO_Prefix'].isin (['00'])) &\
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[-2:] == 'CN'), 'Phase'] = 'CN'

    df.loc[(df['WO_Prefix'].isin (['RW'])), 'Phase'] = 'RW'

    df.loc[(df['WO_Prefix'].isin (['XE'])) &\
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[3] =='CE '), 'Phase'] = 'CE'
    
    df.loc[(df['WO_Prefix'].isin (['XE'])) &\
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[3] !='CE '), 'Phase'] = 'CN'

    df.loc[(df['WO_Prefix'].isin (['XL'])) & \
        ((df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:10] == 'PRE-DESIGN') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:6] == 'PRE-DE') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:4] == 'PRE-') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:3] == 'PRE')), 'Phase'] = 'PD'
    
    df.loc[(df['WO_Prefix'].isin (['XL'])) & \
        ((df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:10] == 'PRE-DESIGN') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:6] == 'PRE-DE') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:4] == 'PRE-') | \
        (df['GRUP_WSDOT_GROUP_DESC'].str.upper().str[:3] == 'PRE') == False), 'Phase'] = 'PE'

    df.loc[(df['WO_Prefix'].isin (['RO'])), 'Phase'] = 'Other'
    
    df.loc[(df['WO_Prefix'].isin (['TA'])) & (df['GRUP_WSDOT_ACTIVITY'].str[-2:] == '01'), 'Phase'] = 'PE'
    df.loc[(df['WO_Prefix'].isin (['TA'])) & (df['GRUP_WSDOT_ACTIVITY'].str[-2:] == '02'), 'Phase'] = 'RW'
    df.loc[(df['WO_Prefix'].isin (['TA'])) & (df['GRUP_WSDOT_ACTIVITY'].str[-2:] == '03'), 'Phase'] = 'CE'
    df.loc[(df['WO_Prefix'].isin (['TA'])) & (df['GRUP_WSDOT_ACTIVITY'].str[-2:] == '04'), 'Phase'] = 'CN'
    df.loc[(df['WO_Prefix'].isin (['TA'])) & (df['GRUP_WSDOT_ACTIVITY'].str[-2:] == '**'), 'Phase'] = 'Other'

    df.loc[(df['WO_Prefix'].isin (['DM'])), 'Phase'] = 'EMER'

    # this rule was a typo in the GRUP ACTPL mapping WORKING DRAFT 20241031
    # df.loc[(df['GRUP_WSDOT_PROJ_FED_2'].isna()) & (df['GRUP_WSDOT_PROJ_LOC_2'].isna()), 'Phase'] = ''

# %%
# Prefixes 00, RW, XE, XL, TA, RO, DM, Categories A, B, C, D(df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
# GRUPmapping
# put code here
# reviist!!!

# (df['WSDOT-CNTRL-SEC-IND'] == 'Y') & (df['WSDOT-PIN-IND'] == 'Y')
# (df['GRUP_WSDOT_PROJ_FED_2'] != '') & (df['GRUP_WSDOT_PROJ_LOC_2'] == '')
df_A3a = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
            (df['GRUP_WSDOT_STATUS'] == 'O') &\
            (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'Y') &\
            (df['GRUP_WSDOT-PIN-IND'] == 'Y') &\
            (df['GRUP_WSDOT_PROJ_FED_2'].notna())
            # &\ (df['GRUP_WSDOT_PROJ_LOC_2'].isna())
'''
df.loc[df_A3a, 'Major Program'] = mjprg_rules(df)
df.loc[df_A3a, 'Major Program'] = 'Major Program'
df.loc[df_A3a, 'Program'] = prg_rules(df)
df.loc[df_A3a, 'Phase'] = phprg_rules(df)
df.loc[df_A3a, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_A3a, 'Program Period'] = ''
df.loc[df_A3a, 'Test df_A3a'] = 'df_A3a'

# (df['GRUP_WSDOT_PROJ_FED_2'] == '') & (df['GRUP_WSDOT_PROJ_LOC_2'] != '')
df_A3b = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'Y') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'Y') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].notna())
'''
df.loc[df_A3b, 'Major Program'] = mjprg_rules(df)
df.loc[df_A3b, 'Program'] = prg_rules(df)
df.loc[df_A3b, 'Phase'] = phprg_rules(df)
df.loc[df_A3b, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_A3b, 'Program Period'] = ''
df.loc[df_A3b, 'Test df_A3b'] = 'df_A3b'

# (df['GRUP_WSDOT_PROJ_FED_2'] == '') & (df['GRUP_WSDOT_PROJ_LOC_2'] == '')
df_A3c = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'Y') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'Y') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].isna())
'''
df.loc[df_A3c, 'Major Program'] = mjprg_rules(df)
df.loc[df_A3c, 'Program'] = prg_rules(df)
df.loc[df_A3c, 'Phase'] = phprg_rules(df)
df.loc[df_A3c, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_A3c, 'Program Period'] = ''
df.loc[df_A3c, 'Test df_A3c'] = 'df_A3c'

# (df['WSDOT-CNTRL-SEC-IND'] == 'Y') & (df['WSDOT-PIN-IND'] == 'N')
# (df['GRUP_WSDOT_PROJ_FED_2'] != '') & (df['GRUP_WSDOT_PROJ_LOC_2'] == '')
df_B3a = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'Y') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'N') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].notna())
        # &\ (df['GRUP_WSDOT_PROJ_LOC_2'].isna())
'''
df.loc[df_B3a, 'Major Program'] = mjprg_rules(df)
df.loc[df_B3a, 'Program'] = prg_rules(df)
df.loc[df_B3a, 'Phase'] = phprg_rules(df)
df.loc[df_B3a, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_B3a, 'Program Period'] = ''
df.loc[df_B3a, 'Test df_B3a'] = 'df_B3a'

# (df['GRUP_WSDOT_PROJ_FED_2'] == '') & (df['GRUP_WSDOT_PROJ_LOC_2'] != '')
df_B3b = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'Y') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'N') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].notna())
'''
df.loc[df_B3b, 'Major Program'] = mjprg_rules(df)
df.loc[df_B3b, 'Program'] = prg_rules(df)
df.loc[df_B3b, 'Phase'] = phprg_rules(df)
df.loc[df_B3b, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_B3b, 'Program Period'] = ''
df.loc[df_B3b, 'Test df_B3b'] = 'df_B3b'

# (df['GRUP_WSDOT_PROJ_FED_2'] == '') & (df['GRUP_WSDOT_PROJ_LOC_2'] == '')
df_B3c = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'Y') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'N') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].isna())
'''
df.loc[df_B3c, 'Major Program'] = mjprg_rules(df)
df.loc[df_B3c, 'Program'] = prg_rules(df)
df.loc[df_B3c, 'Phase'] = phprg_rules(df)
df.loc[df_B3c, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_B3c, 'Program Period'] = ''
df.loc[df_B3c, 'Test df_B3c'] = 'df_B3c'

# (df['WSDOT-CNTRL-SEC-IND'] == 'N') & (df['WSDOT-PIN-IND'] == 'Y')
# (df['GRUP_WSDOT_PROJ_FED_2'] != '') & (df['GRUP_WSDOT_PROJ_LOC_2'] == '')
df_C3a = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'N') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'Y') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].notna())
        # &\ (df['GRUP_WSDOT_PROJ_LOC_2'].isna())
'''
df.loc[df_C3a, 'Major Program'] = mjprg_rules(df)
df.loc[df_C3a, 'Program'] = prg_rules(df)
df.loc[df_C3a, 'Phase'] = phprg_rules(df)
df.loc[df_C3a, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_C3a, 'Program Period'] = ''
df.loc[df_C3a, 'Test df_C3a'] = 'df_C3a'

# (df['GRUP_WSDOT_PROJ_FED_2'] == '') & (df['GRUP_WSDOT_PROJ_LOC_2'] != '')
df_C3b = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'N') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'Y') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].notna())
'''
df.loc[df_C3b, 'Major Program'] = mjprg_rules(df)
df.loc[df_C3b, 'Program'] = prg_rules(df)
df.loc[df_C3b, 'Phase'] = phprg_rules(df)
df.loc[df_C3b, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_C3b, 'Program Period'] = ''
df.loc[df_C3b, 'Test df_C3b'] = 'df_C3b'

# (df['GRUP_WSDOT_PROJ_FED_2'] == '') & (df['GRUP_WSDOT_PROJ_LOC_2'] == '')
df_C3c = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'N') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'Y') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].isna())
'''
df.loc[df_C3c, 'Major Program'] = mjprg_rules(df)
df.loc[df_C3c, 'Program'] = prg_rules(df)
df.loc[df_C3c, 'Phase'] = phprg_rules(df)
df.loc[df_C3c, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_C3c, 'Program Period'] = ''
df.loc[df_C3c, 'Test df_C3c'] = 'df_C3c'

# (df['WSDOT-CNTRL-SEC-IND'] == 'N') & (df['WSDOT-PIN-IND'] == 'N')
# (df['GRUP_WSDOT_PROJ_FED_2'] != '') & (df['GRUP_WSDOT_PROJ_LOC_2'] == '')
df_D3a = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'N') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'N') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].notna())
        # &\ (df['GRUP_WSDOT_PROJ_LOC_2'].isna())
'''
df.loc[df_D3a, 'Major Program'] = mjprg_rules(df)
df.loc[df_D3a, 'Program'] = prg_rules(df)
df.loc[df_D3a, 'Phase'] = phprg_rules(df)
df.loc[df_D3a, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_D3a, 'Program Period'] = ''
df.loc[df_D3a, 'Test df_D3a'] = 'df_D3a'

# (df['GRUP_WSDOT_PROJ_FED_2'] == '') & (df['GRUP_WSDOT_PROJ_LOC_2'] != '')
df_D3b = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'N') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'N') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].notna())
'''
df.loc[df_D3b, 'Major Program'] = mjprg_rules(df)
df.loc[df_D3b, 'Program'] = prg_rules(df)
df.loc[df_D3b, 'Phase'] = phprg_rules(df)
df.loc[df_D3b, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_D3b, 'Program Period'] = ''
df.loc[df_D3b, 'Test df_D3b'] = 'df_D3b'

# (df['GRUP_WSDOT_PROJ_FED_2'] == '') & (df['GRUP_WSDOT_PROJ_LOC_2'] == '')
df_D3c = (df['WO_Prefix'].isin (['00', 'RW', 'XE', 'XL', 'TA', 'RO', 'DM'])) &\
        (df['GRUP_WSDOT_STATUS'] == 'O') &\
        (df['GRUP_WSDOT-CNTRL-SEC-IND'] == 'N') &\
        (df['GRUP_WSDOT-PIN-IND'] == 'N') &\
        (df['GRUP_WSDOT_PROJ_FED_2'].isna()) &\
        (df['GRUP_WSDOT_PROJ_LOC_2'].isna())
'''
df.loc[df_D3c, 'Major Program'] = mjprg_rules(df)
df.loc[df_D3c, 'Program'] = prg_rules(df)
df.loc[df_D3c, 'Phase'] = phprg_rules(df)
df.loc[df_D3c, 'Funding Profile'] = fprfl_rules(df)
'''
df.loc[df_D3c, 'Program Period'] = ''
df.loc[df_D3c, 'Test df_D3c'] = 'df_D3c'

mjprg_rules(df)
prg_rules(df)
phprg_rules(df)
fprfl_rules(df)

# %%
# begin fields used for testing, will be removed

df.loc[((df['CSPA_WSDOT-CNTRL-SECT'] == '')), 'Test Field 01'] = 'CNTRL-SECT_empty'

df.loc[((df['CSPA_WSDOT-CNTRL-SECT'].isna())), 'Test Field 02'] = 'CNTRL-SECT_isna'

df.loc[((df['CSPA_WSDOT-CNTRL-SECT'].isnull())), 'Test Field 03'] = 'CNTRL-SECT_isnull'

df.loc[((df['CSPA_WSDOT-PIN'] == '')), 'Test Field 04'] = 'CSPA_WSDOT-PIN_empty'

df.loc[((df['CSPA_WSDOT-PIN'].isna())), 'Test Field 05'] = 'CSPA_WSDOT-PIN_isna'

df.loc[((df['CSPA_WSDOT-PIN'].isnull())), 'Test Field 06'] = 'CSPA_WSDOT-PIN_isnull'

df.loc[((df['GRUP_WSDOT_PROJ_FED_2'] == '')), 'Test Field 07'] = 'FED_2_empty'

df.loc[((df['GRUP_WSDOT_PROJ_FED_2'].isna())), 'Test Field 08'] = 'FED_2_isna'

df.loc[((df['GRUP_WSDOT_PROJ_FED_2'].isnull())), 'Test Field 09'] = 'FED_2_isnull'

df.loc[((df['GRUP_WSDOT_PROJ_LOC_2'] == '')), 'Test Field 10'] = 'LOC_2_empty'

df.loc[((df['GRUP_WSDOT_PROJ_LOC_2'].isna())), 'Test Field 11'] = 'LOC_2_isna'

df.loc[((df['GRUP_WSDOT_PROJ_LOC_2'].isnull())), 'Test Field 12'] = 'LOC_2_isnull'

df.loc[((df['GRUP_WSDOT_APPR_STA'] == '')), 'Test Field 13'] = 'APPR_STA_empty'

df.loc[((df['GRUP_WSDOT_APPR_STA'].isna())), 'Test Field 14'] = 'APPR_STA_isna'

df.loc[((df['GRUP_WSDOT_APPR_STA'].isnull())), 'Test Field 15'] = 'APPR_STA_isnull'

# end fields used for testing, will be removed

# %%
# Budget Program A
# put code here

# %%
# Budget Program B
# put code here

# %%
# Budget Program C
# put code here

# MJPRGrules
df.loc[(df['WO_Prefix'].isin (['SM', 'SD'])) &\
    (df['GRUP_WSDOT_PROJ_LOC_2'].notna()), 'Major Program'] = 'REIMB'
df.loc[(df['WO_Prefix'].isin (['SD'])) &\
    (df['GRUP_WSDOT_PROJ_LOC_2'].isna()), 'Major Program'] = 'TECH'
df.loc[(df['WO_Prefix'].isin (['SM'])) &\
    (df['GRUP_WSDOT_PROJ_LOC_2'].isna()), 'Major Program'] = 'ITOPS'

# PROGrules
df.loc[(df['WO_Prefix'].isin (['SM', 'SD'])) &\
    (df['GRUP_WSDOT_PROJ_LOC_2'].notna()), 'Program'] = df['GRUP_WSDOT_PROJ_LOC_2'].str[:7]
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8225'])), 'Program'] =  'ONEWA PRJ'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8226'])), 'Program'] =  'PROPEL PRJ'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8227'])), 'Program'] =  'DATACNT'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8230'])), 'Program'] =  'REMUPG PRJ'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD0881'])), 'Program'] =  'NWITS'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD0882'])), 'Program'] =  'NCITS'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD0884'])), 'Program'] =  'OR_SWITS'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD0885'])), 'Program'] =  'SCITS'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD0886'])), 'Program'] =  'ERITS'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8242'])), 'Program'] =  'BADM'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8243'])), 'Program'] =  'FIELD'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8244'])), 'Program'] =  'INFRA'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8245'])), 'Program'] =  'IMP'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8246'])), 'Program'] =  'APPS'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8247'])), 'Program'] =  'SOFTCN'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8251'])), 'Program'] =  'DTMGT'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8253'])), 'Program'] =  'NETSEC'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8254'])), 'Program'] =  'FITS'
df.loc[(df['GRUP_WSDOT_WORK_ORDER'].isin (['SD8263'])), 'Program'] =  'CYBER'

# PHPROGrules
df.loc[(df['WO_Prefix'].isin (['SM', 'SD'])) &\
    (df['GRUP_WSDOT_PROJ_LOC_2'].notna()), 'Phase'] = 'Other'

# TASKORDrules

# PPCrules
df.loc[(df['WO_Prefix'].isin (['SM', 'SD'])) &\
    (df['GRUP_WSDOT_PROJ_LOC_2'].isna()), 'Program Period'] = '25-27'

#FUNDACTVAPPRrules
df.loc[(df['WO_Prefix'].isin (['AD', 'AP'])), 'Fund'] = df['GRUP_FUND']
df.loc[(df['WO_Prefix'].isin (['AD', 'AP'])), 'Activity'] = df['GRUP_WSDOT_ACTIVITY']
df.loc[(df['WO_Prefix'].isin (['AD', 'AP'])), 'Appr Unit'] = df['GRUP_WSDOT_APPR_STA']

# %%
# Budget Program E
# put code here

df.loc[(df['Budget_Program'] == 'E'), 'Task Order'] = df['GRUP_WSDOT_WORK_ORDER']
df.loc[(df['Budget_Program'] == 'E'), 'Fund'] = df['GRUP_FUND']
df.loc[(df['Budget_Program'] == 'E'), 'Appr Unit'] = df['GRUP_WSDOT_APPR_STA']
df.loc[(df['Budget_Program'] == 'E'), 'Activity'] = df['GRUP_WSDOT_ACTIVITY']
df.loc[(df['Budget_Program'] == 'E'), ['Major Program', 'Program']] = ['3PTYDM', 'DMTEF']

# %%
# Budget Program X
# put code here

# %%
# print off csv file, change path

df.to_csv('C:\WSDOTLocal\conversion_actpl_draft_test_20241112_with_all_fields.csv')

df = df[[
    'WORD_WSDOT_WO_DESCRIPTION',
    'GRUP_WSDOT_WORK_ORDER',
    'GRUP_WSDOT_GROUP',
    'GRUP_WSDOT_GROUP_DESC',
    'GRUP_WSDOT_STATUS',
    'GRUP_WSDOT_PROJ_FED_2', 
    'GRUP_WSDOT_PROJ_LOC_2',
    'GRUP_FUND',
    'GRUP_WSDOT_APPR_STA',
    'GRUP_WSDOT_ACTIVITY',
    'GRUP_WSDOT-CNTRL-SEC-IND',
    'GRUP_WSDOT-PIN-IND',
    'GRUP_WSDOT-LABOR-IND',
    'GRUP_WSDOT-PARCEL-IND',
    'GRUP_WSDOT-PAY-AGREE-2',
    'GRUP_WSDOT-DAMAGE-CODE',
    'GRUP_WSDOT-FIN-CD-FED', 
    'GRUP_WSDOT-FIN-CD-LOC', 
    'GRUP_WSDOT-FIN-CD-STA',
    'CSPA_WSDOT-CNTRL-SECT',
    'CSPA_WSDOT-PIN',
    'PFST_PROGRAM_PROVIDER',
    'Flag 1 Labor Ind',	
    'Flag 2 Cntrl Sec Ind',	
    'Flag 3 Pin Ind',	
    'Flag 4 Parcel Ind',
    'Budget_Program',
    'Budget_Sub_Program',
    'WO_Prefix',
    'Accounting Template',
    'Name',
    'Description',
    'Major Program', 
    'Program', 
    'Phase', 
    'Program Period',
    'Funding Profile',
    'Task',  
    'Task Order', 
    'Fund',
    'Appr Unit',
    'Activity',
    'Location'
]].copy()

df.to_csv('C:\WSDOTLocal\conversion_actpl_draft_test_20241112.csv')

print('Complete')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:51: SyntaxWarning: invalid escape sequence '\W'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:51: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\gulleyj\AppData\Local\Temp\ipykernel_27812\3359672291.py:3: SyntaxWarning: invalid escape sequence '\W'
#   df.to_csv('C:\WSDOTLocal\conversion_actpl_draft_test_20241112_with_all_fields.csv')
# C:\Users\gulleyj\AppData\Local\Temp\ipykernel_27812\3359672291.py:51: SyntaxWarning: invalid escape sequence '\W'
#   df.to_csv('C:\WSDOTLocal\conversion_actpl_draft_test_20241112.csv')
# Complete
